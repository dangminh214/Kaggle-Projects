# %%
import tensorflow as tf
from tensorflow import keras

import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Context**
#
# Fashion-MNIST is a dataset of Zalando's article images—consisting of a training set of 60,000 examples and a test set of 10,000 examples. Each example is a 28x28 grayscale image, associated with a label from 10 classes. Zalando intends Fashion-MNIST to serve as a direct drop-in replacement for the original MNIST dataset for benchmarking machine learning algorithms. It shares the same image size and structure of training and testing splits.
#
# The original MNIST dataset contains a lot of handwritten digits. Members of the AI/ML/Data Science community love this dataset and use it as a benchmark to validate their algorithms. In fact, MNIST is often the first dataset researchers try. "If it doesn't work on MNIST, it won't work at all", they said. "Well, if it does work on MNIST, it may still fail on others."
#
# Zalando seeks to replace the original MNIST dataset

# %% [markdown]
# Keras support loading the data source directly

# %% [markdown]
# **Import data**
#
# Import data from MNIST Fashion dataset

# %%
fashion_mnist = keras.datasets.fashion_mnist
(train_images, train_labels), (test_images, test_labels) = fashion_mnist.load_data()

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
train_labels.shape
# Out:
# (60000,)

# %% [markdown]
# **Preprocess data**
#
# Sample: show the first image of the dataset

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %% [markdown]
# **Visualize the image inside dataset**
#
# Test with the first index in the dataset

# %%
plt.figure()
plt.imshow(train_images[0])
plt.colorbar()
plt.gca().grid(False)

# %% [markdown]
# Normalize the data, make them between 0,1
#
# Because each value in range 0,255

# %%
train_images = train_images / 255
test_images = test_images / 255

# %% [markdown]
# Debug shape of images

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
test_labels
# Out:
# array([9, 2, 1, ..., 8, 1, 5], dtype=uint8)

# %% [markdown]
# **Define class name of classify classes**
#
# Base on the description of the dataset, there are total 10 different classes for clothes

# %%
class_names = ["T-shirt/top", "Trouser", "Pullover", "Dress", "Coat", "Sandal", "Shirt", "Sneaker", "Bag", "Ankle Boot"]

# %%
plt.figure(figsize=(10, 10))
for i in range(25): # Show the first 25 items as sample
    plt.subplot(5,5,i+1)      # 5 row 5 column, each row has 5 items
    plt.xticks([])
    plt.yticks([])
    plt.imshow(train_images[i])
    plt.xlabel(class_names[train_labels[i]])

# %%
model = keras.Sequential([
    keras.Input(shape=(28,28,1)), #(28x28)is size of an image, input layer gets size of each image 1 means one channel color -> gray scale
    keras.layers.Conv2D(64, (3,3), activation="relu"),
    keras.layers.MaxPooling2D(2,2),
    keras.layers.Conv2D(64, (3,3), activation="relu"), 
    keras.layers.MaxPooling2D(2,2),
    keras.layers.Flatten(),
    keras.layers.Dense(128, activation=tf.nn.relu),
    keras.layers.Dense(10, activation=tf.nn.softmax)        # Classify into 10 class names
])

# %%
model.compile(
    optimizer=tf.keras.optimizers.Adam(),  # Correct way in TensorFlow 2.x
    loss="sparse_categorical_crossentropy",  # Fixed typo
    metrics=['accuracy']
)

# %%
model.fit(train_images, train_labels, epochs=5)
# Out:
# Epoch 1/5
# 2025-03-05 23:27:40.191251: W external/local_xla/xla/tsl/framework/cpu_allocator_impl.cc:83] Allocation of 188160000 exceeds 10% of free system memory.
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 39s 20ms/step - accuracy: 0.8172 - loss: 0.5116
# Epoch 2/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 39s 21ms/step - accuracy: 0.9059 - loss: 0.2611
# Epoch 3/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 38s 20ms/step - accuracy: 0.9210 - loss: 0.2090
# Epoch 4/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 37s 20ms/step - accuracy: 0.9347 - loss: 0.1730
# Epoch 5/5
# 1875/1875 ━━━━━━━━━━━━━━━━━━━━ 38s 20ms/step - accuracy: 0.9474 - loss: 0.1433

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)

print("Test Accuracy: ", test_acc)
print("Test Loss: ", test_loss)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - accuracy: 0.9079 - loss: 0.2822
# Test Accuracy:  0.9088000059127808
# Test Loss:  0.2702583372592926

# %%
predictions = model.predict(test_images)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step

# %% [markdown]
# Test output, show the first value of predictions array

# %%
np.argmax(predictions[0])
# Out:
# np.int64(9)

# %% [markdown]
# Now, plot to see the predictions on different images(here show for 100 images)

# %%
plt.figure(figsize=(10, 10))
for i in range(100):
    plt.subplot(10, 10, i+1),
    plt.xticks([]),
    plt.yticks([]),
    plt.imshow(test_images[i])
    predicted_label=(np.argmax(predictions[i]))
    true_label=test_labels[i]
    if predicted_label == true_label:
        color="green"
    else:
        color="red"

    plt.title(
        "Predict: {}\n(True: {})".format(
            class_names[predicted_label],
            class_names[true_label],
            color=color
        ),
        fontsize=8
    )

plt.tight_layout()  # adjust distance between subplot to avoid overlap
plt.show()
